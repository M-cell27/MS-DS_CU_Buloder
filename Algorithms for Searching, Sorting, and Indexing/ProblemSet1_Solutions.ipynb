# %% [markdown]
# ## Instructions
#
# > This assignment is to be completed and uploaded as a python3 notebook.

# %% [markdown]
# This problem set covers the following topics:
#   - Basics of algorithms: correctness and running time complexity.
#   - Time Complexity: O, big-Omega and big-Theta Notations.
#   - Proving Correctness of Algorithms through Inductive Invariants.
#   - Merge Sort: Proving Correctness.
#
# __Important Note__
#
# Although this is a programming assignment, we have asked you to work on the "design" and provided opportunities for you to analyze your solution and describe your design. __However, those parts will not be graded.__ You are welcome to compare your answers against our solutions once you have completed the assignments. Our solutions are provided at the very end.

# %% [markdown]
# ## Problem 1: Find Crossover Indices.
#
# You are given data that consists of points
# $(x_0, y_0), \ldots, (x_n, y_n)$, wherein $x_0 < x_1 < \ldots < x_n $, and  $y_0 < y_1 \ldots < y_n$ as well.
#
# Furthermore, it is given that $y_0 < x_0$ and $ y_n > x_n$.
#
# Find a "cross-over" index $i$ between $0$ and $n-1$ such that  $ y_i \leq x_i$ and $y_{i+1} > x_{i+1}$.
#
# Note that such an index must always exist (convince yourself of this fact before we proceed).
#
#
# __Example__
#
# $$\begin{array}{c| c c c c c c c c c }
# i & 0 & 1 & 2 & 3 & 4 & 5 & 6 & 7 \\
# \hline
# x_i & 0 & 2 & 4 & \color{red}{5} & \color{red}{6} & 7 & 8 & 10 \\
# y_i & -2 & 0 & 2 & \color{red}{4} & \color{red}{7} & 8 & 10 & 12 \\
# \end{array} $$
#
#
# Your algorithm must find the index $i=3$ as the crossover point.
#
# On the other hand, consider the data
#
# $$\begin{array}{c| c c c c c c c c c }
# i & 0 & 1 & 2 & 3 & 4 & 5 & 6 & 7 \\
# \hline
# x_i & \color{red}{0} & \color{red}{1} & 4 & \color{red}{5} & \color{red}{6} & 7 & 8 & 10 \\
# y_i & \color{red}{-2} & \color{red}{1.5} & 2 & \color{red}{4} & \color{red}{7} & 8 & 10 & 12 \\
# \end{array} $$
#
# We have two cross over points. Your algorithm may output either $i=0$ or $i=3$.

# %% [markdown]
# __(A)__ Design an algorithm to find an index $i \in \{ 0, 1, \ldots, n-1\}$ such that $x_i \geq y_i$ but $x_{i+1} < y_{i+1}$.
#
# Describe your algorithm using python code for a function _findCrossoverIndexHelper(x, y, left, right)_
#   - `x` is a list of x values sorted in increasing order.
#   - `y` is a list of y values sorted in increasing order.
#   - `x` and `y` are lists of same size (`n`).
#   - `left` and `right` are indices that represent the current search region in the list such that 0 <= `left` < `right` <= `n`
#
# Your solution must use _recursion_.
#
# **Hint:** Modify the binary search algorithm we presented in class.

# %%
#First write a "helper" function with two extra parameters
# left, right that ddedscribes the search region as shown below
def findCrossoverIndexHelper(x, y, left, right):
    # Note: Output index i such that 
    #         left <= i <= right
    #         x[i] <= y[i]
    # First, Write down our invariants as assertions here
    assert(len(x) == len(y))
    assert(left >= 0)
    assert(left <= right-1)
    assert(right < len(x))
    # Here is the key property we would like to maintain.
    assert(x[left] > y[left])
    assert(x[right] < y[right])
    
    # your code here

def findCrossoverIndexHelper(x, y, left, right):
    if left >= right:
        # Base case: If the search region is reduced to a single element or empty,
        # return False, indicating that the element is not in x.
        return False

    mid = (left + right) // 2  # Calculate the midpoint of the search region

    if x[mid] > y[mid] and x[mid + 1] < y[mid + 1]:
        # Crossover condition met, return the index i.
        return mid
    
    if x[mid] > y[mid]:
        # If x[mid] > y[mid], but x[mid + 1] >= y[mid + 1], search in the right half.
        return findCrossoverIndexHelper(x, y, left=mid + 1, right=right)
    else:
        # If x[mid] <= y[mid], search in the left half.
        return findCrossoverIndexHelper(x, y, left=left, right=mid - 1)

# %%
#Define the function findCrossoverIndex that wil 
# call the helper function findCrossoverIndexHelper
def findCrossoverIndex(x, y):
    assert(len(x) == len(y))
    assert(x[0] > y[0])
    n = len(x)
    assert(x[n-1] < y[n-1]) # Note: this automatically ensures n >= 2 why?
    print("\nInitiate test")
    # Call the helper function to find the crossover index within the entire range
    return findCrossoverIndexHelper(x, y, 0, n - 1)

# %%
# BEGIN TEST CASES
j1 = findCrossoverIndex([0, 1, 2, 3, 4, 5, 6, 7], [-2, 0, 4, 5, 6, 7, 8, 9])
print('j1 = %d' % j1)
assert j1 == 1, "Test Case # 1 Failed"

j2 = findCrossoverIndex([0, 1, 2, 3, 4, 5, 6, 7], [-2, 0, 4, 4.2, 4.3, 4.5, 8, 9])
print('j2 = %d' % j2)
assert j2 == 1 or j2 == 5, "Test Case # 2 Failed"

j3 = findCrossoverIndex([0, 1], [-10, 10])
print('j3 = %d' % j3)
assert j3 == 0, "Test Case # 3 failed"

j4 = findCrossoverIndex([0,1, 2, 3], [-10, -9, -8, 5])
print('j4 = %d' % j4)
assert j4 == 2, "Test Case # 4 failed"

print('Congratulations: all test cases passed - 10 points')
#END TEST CASES
# Out:
# Initiate test
# j1 = 1
#
# Initiate test
# j2 = 1
#
# Initiate test
# j3 = 0
#
# Initiate test
# j4 = 2
# Congratulations: all test cases passed - 10 points

# %% [markdown]
# __(B, 0 points)__ What is the running time of your algorithm above as a function of the input array size $n$?
#
# __This portion is not graded. You are encouraged to answer it as part of your programming assignment however__

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Problem 2 (Find integer cube root.)
#
# The integer cube root of a positive number $n$ is the smallest number $i$ such that $i^3 \leq n$ but $(i+1)^3 > n$.
#
# For instance, the integer cube root of $100$ is $4$ since $4^3 \leq 100$ but $5^3 > 100$. Likewise, the integer cube root of $1000$ is $10$.
#
# Write a function `integerCubeRootHelper(n, left, right)` that searches for the integer cube-root of `n` between `left` and `right` given the following pre-conditions:
#   - $n \geq 1$
#   - $\text{left} < \text{right}$.
#   - $\text{left}^3 < n$
#   - $\text{right}^3 > n$.

# %%
def integerCubeRootHelper(n, left, right):
    cube = lambda x: x * x * x # anonymous function to cube a number
    assert(n >= 1)
    assert(left < right)
    assert(left >= 0)
    assert(right < n)
    assert(cube(left) < n), f'{left}, {right}'
    assert(cube(right) > n), f'{left}, {right}'
    # your code here
    print(f"Pointers: L:{left}, R:{right}")
    
    mid = (left + right) // 2  # Calculate the midpoint of the search region
    
    print(f"N: {n}, Mid: {mid}, Cube:{cube(mid)}")
    
    if cube(mid) <= n and cube(mid + 1) > n:
        # Crossover condition met, return the result.
        print(f"Solved: n = {mid}\n")
        return mid
    elif cube(mid) > n:
        # If the cube of mid is greater than n, search in the left half.
        return integerCubeRootHelper(n, left=left, right=mid)
    else:
        # If the cube of mid is less than n, search in the right half.
        return integerCubeRootHelper(n, left=mid, right=right)

# %%
# Write down the main function
def integerCubeRoot(n):
    assert( n > 0)
    if (n == 1): 
        return 1
    if (n == 2):
        return 1
    return integerCubeRootHelper(n, 0, n-1)

# %%
assert(integerCubeRoot(1) == 1)
assert(integerCubeRoot(2) == 1)
assert(integerCubeRoot(4) == 1)
assert(integerCubeRoot(7) == 1)
assert(integerCubeRoot(8) == 2)
assert(integerCubeRoot(20) == 2)
assert(integerCubeRoot(26) == 2)
for j in range(27, 64):
    assert(integerCubeRoot(j) == 3)
for j in range(64,125):
    assert(integerCubeRoot(j) == 4)
for j in range(125, 216):
    assert(integerCubeRoot(j) == 5)
for j in range(216, 343):
    assert(integerCubeRoot(j) == 6)
for j in range(343, 512):
    assert(integerCubeRoot(j) == 7)
print('Congrats: All tests passed! (10 points)')
# Out:
# Pointers: L:0, R:3
# N: 4, Mid: 1, Cube:1
# Solved: n = 1
#
# Pointers: L:0, R:6
# N: 7, Mid: 3, Cube:27
# Pointers: L:0, R:3
# N: 7, Mid: 1, Cube:1
# Solved: n = 1
#
# Pointers: L:0, R:7
# N: 8, Mid: 3, Cube:27
# Pointers: L:0, R:3
# N: 8, Mid: 1, Cube:1
# Pointers: L:1, R:3
# N: 8, Mid: 2, Cube:8
# Solved: n = 2
#
# Pointers: L:0, R:19
# N: 20, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 20, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 20, Mid: 2, Cube:8
# Solved: n = 2
#
# Pointers: L:0, R:25
# N: 26, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 26, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 26, Mid: 3, Cube:27
# Pointers: L:0, R:3
# N: 26, Mid: 1, Cube:1
# Pointers: L:1, R:3
# N: 26, Mid: 2, Cube:8
# Solved: n = 2
#
# Pointers: L:0, R:26
# N: 27, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 27, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 27, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:27
# N: 28, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 28, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 28, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:28
# N: 29, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 29, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 29, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:29
# N: 30, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 30, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 30, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:30
# N: 31, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 31, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 31, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:31
# N: 32, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 32, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 32, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:32
# N: 33, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 33, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 33, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 33, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 33, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:33
# N: 34, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 34, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 34, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 34, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 34, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:34
# N: 35, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 35, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 35, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 35, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 35, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:35
# N: 36, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 36, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 36, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 36, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 36, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:36
# N: 37, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 37, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 37, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 37, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 37, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:37
# N: 38, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 38, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 38, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 38, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 38, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:38
# N: 39, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 39, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 39, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 39, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 39, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:39
# N: 40, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 40, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 40, Mid: 4, Cube:64
# Pointers: L:0, R:4
# N: 40, Mid: 2, Cube:8
# Pointers: L:2, R:4
# N: 40, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:40
# N: 41, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 41, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 41, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 41, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 41, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:41
# N: 42, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 42, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 42, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 42, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 42, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:42
# N: 43, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 43, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 43, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 43, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 43, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:43
# N: 44, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 44, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 44, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 44, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 44, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:44
# N: 45, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 45, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 45, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 45, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 45, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:45
# N: 46, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 46, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 46, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 46, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 46, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:46
# N: 47, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 47, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 47, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 47, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 47, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:47
# N: 48, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 48, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 48, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 48, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 48, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:48
# N: 49, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 49, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 49, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 49, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:49
# N: 50, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 50, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 50, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 50, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:50
# N: 51, Mid: 25, Cube:15625
# Pointers: L:0, R:25
# N: 51, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 51, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 51, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:51
# N: 52, Mid: 25, Cube:15625
# Pointers: L:0, R:25
# N: 52, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 52, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 52, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:52
# N: 53, Mid: 26, Cube:17576
# Pointers: L:0, R:26
# N: 53, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 53, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 53, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:53
# N: 54, Mid: 26, Cube:17576
# Pointers: L:0, R:26
# N: 54, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 54, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 54, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:54
# N: 55, Mid: 27, Cube:19683
# Pointers: L:0, R:27
# N: 55, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 55, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 55, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:55
# N: 56, Mid: 27, Cube:19683
# Pointers: L:0, R:27
# N: 56, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 56, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 56, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:56
# N: 57, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 57, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 57, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 57, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:57
# N: 58, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 58, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 58, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 58, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:58
# N: 59, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 59, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 59, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 59, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:59
# N: 60, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 60, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 60, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 60, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:60
# N: 61, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 61, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 61, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 61, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:61
# N: 62, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 62, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 62, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 62, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:62
# N: 63, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 63, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 63, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 63, Mid: 3, Cube:27
# Solved: n = 3
#
# Pointers: L:0, R:63
# N: 64, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 64, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 64, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 64, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 64, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 64, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:64
# N: 65, Mid: 32, Cube:32768
# Pointers: L:0, R:32
# N: 65, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 65, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 65, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:65
# N: 66, Mid: 32, Cube:32768
# Pointers: L:0, R:32
# N: 66, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 66, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 66, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:66
# N: 67, Mid: 33, Cube:35937
# Pointers: L:0, R:33
# N: 67, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 67, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 67, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:67
# N: 68, Mid: 33, Cube:35937
# Pointers: L:0, R:33
# N: 68, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 68, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 68, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:68
# N: 69, Mid: 34, Cube:39304
# Pointers: L:0, R:34
# N: 69, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 69, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 69, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:69
# N: 70, Mid: 34, Cube:39304
# Pointers: L:0, R:34
# N: 70, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 70, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 70, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:70
# N: 71, Mid: 35, Cube:42875
# Pointers: L:0, R:35
# N: 71, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 71, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 71, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:71
# N: 72, Mid: 35, Cube:42875
# Pointers: L:0, R:35
# N: 72, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 72, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 72, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:72
# N: 73, Mid: 36, Cube:46656
# Pointers: L:0, R:36
# N: 73, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 73, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 73, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:73
# N: 74, Mid: 36, Cube:46656
# Pointers: L:0, R:36
# N: 74, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 74, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 74, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:74
# N: 75, Mid: 37, Cube:50653
# Pointers: L:0, R:37
# N: 75, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 75, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 75, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:75
# N: 76, Mid: 37, Cube:50653
# Pointers: L:0, R:37
# N: 76, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 76, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 76, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:76
# N: 77, Mid: 38, Cube:54872
# Pointers: L:0, R:38
# N: 77, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 77, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 77, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:77
# N: 78, Mid: 38, Cube:54872
# Pointers: L:0, R:38
# N: 78, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 78, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 78, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:78
# N: 79, Mid: 39, Cube:59319
# Pointers: L:0, R:39
# N: 79, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 79, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 79, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:79
# N: 80, Mid: 39, Cube:59319
# Pointers: L:0, R:39
# N: 80, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 80, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 80, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:80
# N: 81, Mid: 40, Cube:64000
# Pointers: L:0, R:40
# N: 81, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 81, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 81, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 81, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 81, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 81, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:81
# N: 82, Mid: 40, Cube:64000
# Pointers: L:0, R:40
# N: 82, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 82, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 82, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 82, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 82, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 82, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:82
# N: 83, Mid: 41, Cube:68921
# Pointers: L:0, R:41
# N: 83, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 83, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 83, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 83, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 83, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 83, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:83
# N: 84, Mid: 41, Cube:68921
# Pointers: L:0, R:41
# N: 84, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 84, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 84, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 84, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 84, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 84, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:84
# N: 85, Mid: 42, Cube:74088
# Pointers: L:0, R:42
# N: 85, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 85, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 85, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 85, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 85, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 85, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:85
# N: 86, Mid: 42, Cube:74088
# Pointers: L:0, R:42
# N: 86, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 86, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 86, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 86, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 86, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 86, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:86
# N: 87, Mid: 43, Cube:79507
# Pointers: L:0, R:43
# N: 87, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 87, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 87, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 87, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 87, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 87, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:87
# N: 88, Mid: 43, Cube:79507
# Pointers: L:0, R:43
# N: 88, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 88, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 88, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 88, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 88, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 88, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:88
# N: 89, Mid: 44, Cube:85184
# Pointers: L:0, R:44
# N: 89, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 89, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 89, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 89, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 89, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 89, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:89
# N: 90, Mid: 44, Cube:85184
# Pointers: L:0, R:44
# N: 90, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 90, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 90, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 90, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 90, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 90, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:90
# N: 91, Mid: 45, Cube:91125
# Pointers: L:0, R:45
# N: 91, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 91, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 91, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 91, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 91, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 91, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:91
# N: 92, Mid: 45, Cube:91125
# Pointers: L:0, R:45
# N: 92, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 92, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 92, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 92, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 92, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 92, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:92
# N: 93, Mid: 46, Cube:97336
# Pointers: L:0, R:46
# N: 93, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 93, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 93, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 93, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 93, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 93, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:93
# N: 94, Mid: 46, Cube:97336
# Pointers: L:0, R:46
# N: 94, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 94, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 94, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 94, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 94, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 94, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:94
# N: 95, Mid: 47, Cube:103823
# Pointers: L:0, R:47
# N: 95, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 95, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 95, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 95, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 95, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 95, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:95
# N: 96, Mid: 47, Cube:103823
# Pointers: L:0, R:47
# N: 96, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 96, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 96, Mid: 5, Cube:125
# Pointers: L:0, R:5
# N: 96, Mid: 2, Cube:8
# Pointers: L:2, R:5
# N: 96, Mid: 3, Cube:27
# Pointers: L:3, R:5
# N: 96, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:96
# N: 97, Mid: 48, Cube:110592
# Pointers: L:0, R:48
# N: 97, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 97, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 97, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 97, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 97, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:97
# N: 98, Mid: 48, Cube:110592
# Pointers: L:0, R:48
# N: 98, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 98, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 98, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 98, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 98, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:98
# N: 99, Mid: 49, Cube:117649
# Pointers: L:0, R:49
# N: 99, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 99, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 99, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 99, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 99, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:99
# N: 100, Mid: 49, Cube:117649
# Pointers: L:0, R:49
# N: 100, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 100, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 100, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 100, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 100, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:100
# N: 101, Mid: 50, Cube:125000
# Pointers: L:0, R:50
# N: 101, Mid: 25, Cube:15625
# Pointers: L:0, R:25
# N: 101, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 101, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 101, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 101, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:101
# N: 102, Mid: 50, Cube:125000
# Pointers: L:0, R:50
# N: 102, Mid: 25, Cube:15625
# Pointers: L:0, R:25
# N: 102, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 102, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 102, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 102, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:102
# N: 103, Mid: 51, Cube:132651
# Pointers: L:0, R:51
# N: 103, Mid: 25, Cube:15625
# Pointers: L:0, R:25
# N: 103, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 103, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 103, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 103, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:103
# N: 104, Mid: 51, Cube:132651
# Pointers: L:0, R:51
# N: 104, Mid: 25, Cube:15625
# Pointers: L:0, R:25
# N: 104, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 104, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 104, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 104, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:104
# N: 105, Mid: 52, Cube:140608
# Pointers: L:0, R:52
# N: 105, Mid: 26, Cube:17576
# Pointers: L:0, R:26
# N: 105, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 105, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 105, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 105, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:105
# N: 106, Mid: 52, Cube:140608
# Pointers: L:0, R:52
# N: 106, Mid: 26, Cube:17576
# Pointers: L:0, R:26
# N: 106, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 106, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 106, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 106, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:106
# N: 107, Mid: 53, Cube:148877
# Pointers: L:0, R:53
# N: 107, Mid: 26, Cube:17576
# Pointers: L:0, R:26
# N: 107, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 107, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 107, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 107, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:107
# N: 108, Mid: 53, Cube:148877
# Pointers: L:0, R:53
# N: 108, Mid: 26, Cube:17576
# Pointers: L:0, R:26
# N: 108, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 108, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 108, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 108, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:108
# N: 109, Mid: 54, Cube:157464
# Pointers: L:0, R:54
# N: 109, Mid: 27, Cube:19683
# Pointers: L:0, R:27
# N: 109, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 109, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 109, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 109, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:109
# N: 110, Mid: 54, Cube:157464
# Pointers: L:0, R:54
# N: 110, Mid: 27, Cube:19683
# Pointers: L:0, R:27
# N: 110, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 110, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 110, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 110, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:110
# N: 111, Mid: 55, Cube:166375
# Pointers: L:0, R:55
# N: 111, Mid: 27, Cube:19683
# Pointers: L:0, R:27
# N: 111, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 111, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 111, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 111, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:111
# N: 112, Mid: 55, Cube:166375
# Pointers: L:0, R:55
# N: 112, Mid: 27, Cube:19683
# Pointers: L:0, R:27
# N: 112, Mid: 13, Cube:2197
# Pointers: L:0, R:13
# N: 112, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 112, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 112, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:112
# N: 113, Mid: 56, Cube:175616
# Pointers: L:0, R:56
# N: 113, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 113, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 113, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 113, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 113, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 113, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:113
# N: 114, Mid: 56, Cube:175616
# Pointers: L:0, R:56
# N: 114, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 114, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 114, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 114, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 114, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 114, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:114
# N: 115, Mid: 57, Cube:185193
# Pointers: L:0, R:57
# N: 115, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 115, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 115, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 115, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 115, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 115, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:115
# N: 116, Mid: 57, Cube:185193
# Pointers: L:0, R:57
# N: 116, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 116, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 116, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 116, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 116, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 116, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:116
# N: 117, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 117, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 117, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 117, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 117, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 117, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 117, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:117
# N: 118, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 118, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 118, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 118, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 118, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 118, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 118, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:118
# N: 119, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 119, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 119, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 119, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 119, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 119, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 119, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:119
# N: 120, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 120, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 120, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 120, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 120, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 120, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 120, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:120
# N: 121, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 121, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 121, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 121, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 121, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 121, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 121, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:121
# N: 122, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 122, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 122, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 122, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 122, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 122, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 122, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:122
# N: 123, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 123, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 123, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 123, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 123, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 123, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 123, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:123
# N: 124, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 124, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 124, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 124, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 124, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 124, Mid: 5, Cube:125
# Pointers: L:3, R:5
# N: 124, Mid: 4, Cube:64
# Solved: n = 4
#
# Pointers: L:0, R:124
# N: 125, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 125, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 125, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 125, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 125, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 125, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:125
# N: 126, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 126, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 126, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 126, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 126, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 126, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:126
# N: 127, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 127, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 127, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 127, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 127, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 127, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:127
# N: 128, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 128, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 128, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 128, Mid: 7, Cube:343
# Pointers: L:0, R:7
# N: 128, Mid: 3, Cube:27
# Pointers: L:3, R:7
# N: 128, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:128
# N: 129, Mid: 64, Cube:262144
# Pointers: L:0, R:64
# N: 129, Mid: 32, Cube:32768
# Pointers: L:0, R:32
# N: 129, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 129, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 129, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 129, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 129, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:129
# N: 130, Mid: 64, Cube:262144
# Pointers: L:0, R:64
# N: 130, Mid: 32, Cube:32768
# Pointers: L:0, R:32
# N: 130, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 130, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 130, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 130, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 130, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:130
# N: 131, Mid: 65, Cube:274625
# Pointers: L:0, R:65
# N: 131, Mid: 32, Cube:32768
# Pointers: L:0, R:32
# N: 131, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 131, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 131, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 131, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 131, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:131
# N: 132, Mid: 65, Cube:274625
# Pointers: L:0, R:65
# N: 132, Mid: 32, Cube:32768
# Pointers: L:0, R:32
# N: 132, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 132, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 132, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 132, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 132, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:132
# N: 133, Mid: 66, Cube:287496
# Pointers: L:0, R:66
# N: 133, Mid: 33, Cube:35937
# Pointers: L:0, R:33
# N: 133, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 133, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 133, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 133, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 133, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:133
# N: 134, Mid: 66, Cube:287496
# Pointers: L:0, R:66
# N: 134, Mid: 33, Cube:35937
# Pointers: L:0, R:33
# N: 134, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 134, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 134, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 134, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 134, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:134
# N: 135, Mid: 67, Cube:300763
# Pointers: L:0, R:67
# N: 135, Mid: 33, Cube:35937
# Pointers: L:0, R:33
# N: 135, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 135, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 135, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 135, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 135, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:135
# N: 136, Mid: 67, Cube:300763
# Pointers: L:0, R:67
# N: 136, Mid: 33, Cube:35937
# Pointers: L:0, R:33
# N: 136, Mid: 16, Cube:4096
# Pointers: L:0, R:16
# N: 136, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 136, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 136, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 136, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:136
# N: 137, Mid: 68, Cube:314432
# Pointers: L:0, R:68
# N: 137, Mid: 34, Cube:39304
# Pointers: L:0, R:34
# N: 137, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 137, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 137, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 137, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 137, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:137
# N: 138, Mid: 68, Cube:314432
# Pointers: L:0, R:68
# N: 138, Mid: 34, Cube:39304
# Pointers: L:0, R:34
# N: 138, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 138, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 138, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 138, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 138, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:138
# N: 139, Mid: 69, Cube:328509
# Pointers: L:0, R:69
# N: 139, Mid: 34, Cube:39304
# Pointers: L:0, R:34
# N: 139, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 139, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 139, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 139, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 139, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:139
# N: 140, Mid: 69, Cube:328509
# Pointers: L:0, R:69
# N: 140, Mid: 34, Cube:39304
# Pointers: L:0, R:34
# N: 140, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 140, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 140, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 140, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 140, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:140
# N: 141, Mid: 70, Cube:343000
# Pointers: L:0, R:70
# N: 141, Mid: 35, Cube:42875
# Pointers: L:0, R:35
# N: 141, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 141, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 141, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 141, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 141, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:141
# N: 142, Mid: 70, Cube:343000
# Pointers: L:0, R:70
# N: 142, Mid: 35, Cube:42875
# Pointers: L:0, R:35
# N: 142, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 142, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 142, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 142, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 142, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:142
# N: 143, Mid: 71, Cube:357911
# Pointers: L:0, R:71
# N: 143, Mid: 35, Cube:42875
# Pointers: L:0, R:35
# N: 143, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 143, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 143, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 143, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 143, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:143
# N: 144, Mid: 71, Cube:357911
# Pointers: L:0, R:71
# N: 144, Mid: 35, Cube:42875
# Pointers: L:0, R:35
# N: 144, Mid: 17, Cube:4913
# Pointers: L:0, R:17
# N: 144, Mid: 8, Cube:512
# Pointers: L:0, R:8
# N: 144, Mid: 4, Cube:64
# Pointers: L:4, R:8
# N: 144, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 144, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:144
# N: 145, Mid: 72, Cube:373248
# Pointers: L:0, R:72
# N: 145, Mid: 36, Cube:46656
# Pointers: L:0, R:36
# N: 145, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 145, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 145, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 145, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 145, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:145
# N: 146, Mid: 72, Cube:373248
# Pointers: L:0, R:72
# N: 146, Mid: 36, Cube:46656
# Pointers: L:0, R:36
# N: 146, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 146, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 146, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 146, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 146, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:146
# N: 147, Mid: 73, Cube:389017
# Pointers: L:0, R:73
# N: 147, Mid: 36, Cube:46656
# Pointers: L:0, R:36
# N: 147, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 147, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 147, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 147, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 147, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:147
# N: 148, Mid: 73, Cube:389017
# Pointers: L:0, R:73
# N: 148, Mid: 36, Cube:46656
# Pointers: L:0, R:36
# N: 148, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 148, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 148, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 148, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 148, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:148
# N: 149, Mid: 74, Cube:405224
# Pointers: L:0, R:74
# N: 149, Mid: 37, Cube:50653
# Pointers: L:0, R:37
# N: 149, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 149, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 149, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 149, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 149, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:149
# N: 150, Mid: 74, Cube:405224
# Pointers: L:0, R:74
# N: 150, Mid: 37, Cube:50653
# Pointers: L:0, R:37
# N: 150, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 150, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 150, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 150, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 150, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:150
# N: 151, Mid: 75, Cube:421875
# Pointers: L:0, R:75
# N: 151, Mid: 37, Cube:50653
# Pointers: L:0, R:37
# N: 151, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 151, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 151, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 151, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 151, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:151
# N: 152, Mid: 75, Cube:421875
# Pointers: L:0, R:75
# N: 152, Mid: 37, Cube:50653
# Pointers: L:0, R:37
# N: 152, Mid: 18, Cube:5832
# Pointers: L:0, R:18
# N: 152, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 152, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 152, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 152, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:152
# N: 153, Mid: 76, Cube:438976
# Pointers: L:0, R:76
# N: 153, Mid: 38, Cube:54872
# Pointers: L:0, R:38
# N: 153, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 153, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 153, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 153, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 153, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:153
# N: 154, Mid: 76, Cube:438976
# Pointers: L:0, R:76
# N: 154, Mid: 38, Cube:54872
# Pointers: L:0, R:38
# N: 154, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 154, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 154, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 154, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 154, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:154
# N: 155, Mid: 77, Cube:456533
# Pointers: L:0, R:77
# N: 155, Mid: 38, Cube:54872
# Pointers: L:0, R:38
# N: 155, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 155, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 155, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 155, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 155, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:155
# N: 156, Mid: 77, Cube:456533
# Pointers: L:0, R:77
# N: 156, Mid: 38, Cube:54872
# Pointers: L:0, R:38
# N: 156, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 156, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 156, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 156, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 156, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:156
# N: 157, Mid: 78, Cube:474552
# Pointers: L:0, R:78
# N: 157, Mid: 39, Cube:59319
# Pointers: L:0, R:39
# N: 157, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 157, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 157, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 157, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 157, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:157
# N: 158, Mid: 78, Cube:474552
# Pointers: L:0, R:78
# N: 158, Mid: 39, Cube:59319
# Pointers: L:0, R:39
# N: 158, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 158, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 158, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 158, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 158, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:158
# N: 159, Mid: 79, Cube:493039
# Pointers: L:0, R:79
# N: 159, Mid: 39, Cube:59319
# Pointers: L:0, R:39
# N: 159, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 159, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 159, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 159, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 159, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:159
# N: 160, Mid: 79, Cube:493039
# Pointers: L:0, R:79
# N: 160, Mid: 39, Cube:59319
# Pointers: L:0, R:39
# N: 160, Mid: 19, Cube:6859
# Pointers: L:0, R:19
# N: 160, Mid: 9, Cube:729
# Pointers: L:0, R:9
# N: 160, Mid: 4, Cube:64
# Pointers: L:4, R:9
# N: 160, Mid: 6, Cube:216
# Pointers: L:4, R:6
# N: 160, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:160
# N: 161, Mid: 80, Cube:512000
# Pointers: L:0, R:80
# N: 161, Mid: 40, Cube:64000
# Pointers: L:0, R:40
# N: 161, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 161, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 161, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:161
# N: 162, Mid: 80, Cube:512000
# Pointers: L:0, R:80
# N: 162, Mid: 40, Cube:64000
# Pointers: L:0, R:40
# N: 162, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 162, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 162, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:162
# N: 163, Mid: 81, Cube:531441
# Pointers: L:0, R:81
# N: 163, Mid: 40, Cube:64000
# Pointers: L:0, R:40
# N: 163, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 163, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 163, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:163
# N: 164, Mid: 81, Cube:531441
# Pointers: L:0, R:81
# N: 164, Mid: 40, Cube:64000
# Pointers: L:0, R:40
# N: 164, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 164, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 164, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:164
# N: 165, Mid: 82, Cube:551368
# Pointers: L:0, R:82
# N: 165, Mid: 41, Cube:68921
# Pointers: L:0, R:41
# N: 165, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 165, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 165, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:165
# N: 166, Mid: 82, Cube:551368
# Pointers: L:0, R:82
# N: 166, Mid: 41, Cube:68921
# Pointers: L:0, R:41
# N: 166, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 166, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 166, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:166
# N: 167, Mid: 83, Cube:571787
# Pointers: L:0, R:83
# N: 167, Mid: 41, Cube:68921
# Pointers: L:0, R:41
# N: 167, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 167, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 167, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:167
# N: 168, Mid: 83, Cube:571787
# Pointers: L:0, R:83
# N: 168, Mid: 41, Cube:68921
# Pointers: L:0, R:41
# N: 168, Mid: 20, Cube:8000
# Pointers: L:0, R:20
# N: 168, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 168, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:168
# N: 169, Mid: 84, Cube:592704
# Pointers: L:0, R:84
# N: 169, Mid: 42, Cube:74088
# Pointers: L:0, R:42
# N: 169, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 169, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 169, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:169
# N: 170, Mid: 84, Cube:592704
# Pointers: L:0, R:84
# N: 170, Mid: 42, Cube:74088
# Pointers: L:0, R:42
# N: 170, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 170, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 170, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:170
# N: 171, Mid: 85, Cube:614125
# Pointers: L:0, R:85
# N: 171, Mid: 42, Cube:74088
# Pointers: L:0, R:42
# N: 171, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 171, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 171, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:171
# N: 172, Mid: 85, Cube:614125
# Pointers: L:0, R:85
# N: 172, Mid: 42, Cube:74088
# Pointers: L:0, R:42
# N: 172, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 172, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 172, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:172
# N: 173, Mid: 86, Cube:636056
# Pointers: L:0, R:86
# N: 173, Mid: 43, Cube:79507
# Pointers: L:0, R:43
# N: 173, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 173, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 173, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:173
# N: 174, Mid: 86, Cube:636056
# Pointers: L:0, R:86
# N: 174, Mid: 43, Cube:79507
# Pointers: L:0, R:43
# N: 174, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 174, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 174, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:174
# N: 175, Mid: 87, Cube:658503
# Pointers: L:0, R:87
# N: 175, Mid: 43, Cube:79507
# Pointers: L:0, R:43
# N: 175, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 175, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 175, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:175
# N: 176, Mid: 87, Cube:658503
# Pointers: L:0, R:87
# N: 176, Mid: 43, Cube:79507
# Pointers: L:0, R:43
# N: 176, Mid: 21, Cube:9261
# Pointers: L:0, R:21
# N: 176, Mid: 10, Cube:1000
# Pointers: L:0, R:10
# N: 176, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:176
# N: 177, Mid: 88, Cube:681472
# Pointers: L:0, R:88
# N: 177, Mid: 44, Cube:85184
# Pointers: L:0, R:44
# N: 177, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 177, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 177, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:177
# N: 178, Mid: 88, Cube:681472
# Pointers: L:0, R:88
# N: 178, Mid: 44, Cube:85184
# Pointers: L:0, R:44
# N: 178, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 178, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 178, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:178
# N: 179, Mid: 89, Cube:704969
# Pointers: L:0, R:89
# N: 179, Mid: 44, Cube:85184
# Pointers: L:0, R:44
# N: 179, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 179, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 179, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:179
# N: 180, Mid: 89, Cube:704969
# Pointers: L:0, R:89
# N: 180, Mid: 44, Cube:85184
# Pointers: L:0, R:44
# N: 180, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 180, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 180, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:180
# N: 181, Mid: 90, Cube:729000
# Pointers: L:0, R:90
# N: 181, Mid: 45, Cube:91125
# Pointers: L:0, R:45
# N: 181, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 181, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 181, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:181
# N: 182, Mid: 90, Cube:729000
# Pointers: L:0, R:90
# N: 182, Mid: 45, Cube:91125
# Pointers: L:0, R:45
# N: 182, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 182, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 182, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:182
# N: 183, Mid: 91, Cube:753571
# Pointers: L:0, R:91
# N: 183, Mid: 45, Cube:91125
# Pointers: L:0, R:45
# N: 183, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 183, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 183, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:183
# N: 184, Mid: 91, Cube:753571
# Pointers: L:0, R:91
# N: 184, Mid: 45, Cube:91125
# Pointers: L:0, R:45
# N: 184, Mid: 22, Cube:10648
# Pointers: L:0, R:22
# N: 184, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 184, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:184
# N: 185, Mid: 92, Cube:778688
# Pointers: L:0, R:92
# N: 185, Mid: 46, Cube:97336
# Pointers: L:0, R:46
# N: 185, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 185, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 185, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:185
# N: 186, Mid: 92, Cube:778688
# Pointers: L:0, R:92
# N: 186, Mid: 46, Cube:97336
# Pointers: L:0, R:46
# N: 186, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 186, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 186, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:186
# N: 187, Mid: 93, Cube:804357
# Pointers: L:0, R:93
# N: 187, Mid: 46, Cube:97336
# Pointers: L:0, R:46
# N: 187, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 187, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 187, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:187
# N: 188, Mid: 93, Cube:804357
# Pointers: L:0, R:93
# N: 188, Mid: 46, Cube:97336
# Pointers: L:0, R:46
# N: 188, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 188, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 188, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:188
# N: 189, Mid: 94, Cube:830584
# Pointers: L:0, R:94
# N: 189, Mid: 47, Cube:103823
# Pointers: L:0, R:47
# N: 189, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 189, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 189, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:189
# N: 190, Mid: 94, Cube:830584
# Pointers: L:0, R:94
# N: 190, Mid: 47, Cube:103823
# Pointers: L:0, R:47
# N: 190, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 190, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 190, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:190
# N: 191, Mid: 95, Cube:857375
# Pointers: L:0, R:95
# N: 191, Mid: 47, Cube:103823
# Pointers: L:0, R:47
# N: 191, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 191, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 191, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:191
# N: 192, Mid: 95, Cube:857375
# Pointers: L:0, R:95
# N: 192, Mid: 47, Cube:103823
# Pointers: L:0, R:47
# N: 192, Mid: 23, Cube:12167
# Pointers: L:0, R:23
# N: 192, Mid: 11, Cube:1331
# Pointers: L:0, R:11
# N: 192, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:192
# N: 193, Mid: 96, Cube:884736
# Pointers: L:0, R:96
# N: 193, Mid: 48, Cube:110592
# Pointers: L:0, R:48
# N: 193, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 193, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 193, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 193, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 193, Mid: 4, Cube:64
# Pointers: L:4, R:6
# N: 193, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:193
# N: 194, Mid: 96, Cube:884736
# Pointers: L:0, R:96
# N: 194, Mid: 48, Cube:110592
# Pointers: L:0, R:48
# N: 194, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 194, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 194, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 194, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 194, Mid: 4, Cube:64
# Pointers: L:4, R:6
# N: 194, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:194
# N: 195, Mid: 97, Cube:912673
# Pointers: L:0, R:97
# N: 195, Mid: 48, Cube:110592
# Pointers: L:0, R:48
# N: 195, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 195, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 195, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 195, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 195, Mid: 4, Cube:64
# Pointers: L:4, R:6
# N: 195, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:195
# N: 196, Mid: 97, Cube:912673
# Pointers: L:0, R:97
# N: 196, Mid: 48, Cube:110592
# Pointers: L:0, R:48
# N: 196, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 196, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 196, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 196, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 196, Mid: 4, Cube:64
# Pointers: L:4, R:6
# N: 196, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:196
# N: 197, Mid: 98, Cube:941192
# Pointers: L:0, R:98
# N: 197, Mid: 49, Cube:117649
# Pointers: L:0, R:49
# N: 197, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 197, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 197, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 197, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 197, Mid: 4, Cube:64
# Pointers: L:4, R:6
# N: 197, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:197
# N: 198, Mid: 98, Cube:941192
# Pointers: L:0, R:98
# N: 198, Mid: 49, Cube:117649
# Pointers: L:0, R:49
# N: 198, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 198, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 198, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 198, Mid: 3, Cube:27
# Pointers: L:3, R:6
# N: 198, Mid: 4, Cube:64
# Pointers: L:4, R:6
# N: 198, Mid: 5, Cube:125
# Solved: n = 5
#
# Pointers: L:0, R:198
# N: 199, Mid: 99, Cube:970299
# Pointers: L:0, R:99
# N: 199, Mid: 49, Cube:117649
# Pointers: L:0, R:49
# N: 199, Mid: 24, Cube:13824
# Pointers: L:0, R:24
# N: 199, Mid: 12, Cube:1728
# Pointers: L:0, R:12
# N: 199, Mid: 6, Cube:216
# Pointers: L:0, R:6
# N: 199, Mid: 3, Cube:27
# Pointers: L:3, R:6
# ...
# N: 460, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 460, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 460, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:460
# N: 461, Mid: 230, Cube:12167000
# Pointers: L:0, R:230
# N: 461, Mid: 115, Cube:1520875
# Pointers: L:0, R:115
# N: 461, Mid: 57, Cube:185193
# Pointers: L:0, R:57
# N: 461, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 461, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 461, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:461
# N: 462, Mid: 230, Cube:12167000
# Pointers: L:0, R:230
# N: 462, Mid: 115, Cube:1520875
# Pointers: L:0, R:115
# N: 462, Mid: 57, Cube:185193
# Pointers: L:0, R:57
# N: 462, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 462, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 462, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:462
# N: 463, Mid: 231, Cube:12326391
# Pointers: L:0, R:231
# N: 463, Mid: 115, Cube:1520875
# Pointers: L:0, R:115
# N: 463, Mid: 57, Cube:185193
# Pointers: L:0, R:57
# N: 463, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 463, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 463, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:463
# N: 464, Mid: 231, Cube:12326391
# Pointers: L:0, R:231
# N: 464, Mid: 115, Cube:1520875
# Pointers: L:0, R:115
# N: 464, Mid: 57, Cube:185193
# Pointers: L:0, R:57
# N: 464, Mid: 28, Cube:21952
# Pointers: L:0, R:28
# N: 464, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 464, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:464
# N: 465, Mid: 232, Cube:12487168
# Pointers: L:0, R:232
# N: 465, Mid: 116, Cube:1560896
# Pointers: L:0, R:116
# N: 465, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 465, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 465, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 465, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:465
# N: 466, Mid: 232, Cube:12487168
# Pointers: L:0, R:232
# N: 466, Mid: 116, Cube:1560896
# Pointers: L:0, R:116
# N: 466, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 466, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 466, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 466, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:466
# N: 467, Mid: 233, Cube:12649337
# Pointers: L:0, R:233
# N: 467, Mid: 116, Cube:1560896
# Pointers: L:0, R:116
# N: 467, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 467, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 467, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 467, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:467
# N: 468, Mid: 233, Cube:12649337
# Pointers: L:0, R:233
# N: 468, Mid: 116, Cube:1560896
# Pointers: L:0, R:116
# N: 468, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 468, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 468, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 468, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:468
# N: 469, Mid: 234, Cube:12812904
# Pointers: L:0, R:234
# N: 469, Mid: 117, Cube:1601613
# Pointers: L:0, R:117
# N: 469, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 469, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 469, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 469, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:469
# N: 470, Mid: 234, Cube:12812904
# Pointers: L:0, R:234
# N: 470, Mid: 117, Cube:1601613
# Pointers: L:0, R:117
# N: 470, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 470, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 470, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 470, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:470
# N: 471, Mid: 235, Cube:12977875
# Pointers: L:0, R:235
# N: 471, Mid: 117, Cube:1601613
# Pointers: L:0, R:117
# N: 471, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 471, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 471, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 471, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:471
# N: 472, Mid: 235, Cube:12977875
# Pointers: L:0, R:235
# N: 472, Mid: 117, Cube:1601613
# Pointers: L:0, R:117
# N: 472, Mid: 58, Cube:195112
# Pointers: L:0, R:58
# N: 472, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 472, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 472, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:472
# N: 473, Mid: 236, Cube:13144256
# Pointers: L:0, R:236
# N: 473, Mid: 118, Cube:1643032
# Pointers: L:0, R:118
# N: 473, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 473, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 473, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 473, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:473
# N: 474, Mid: 236, Cube:13144256
# Pointers: L:0, R:236
# N: 474, Mid: 118, Cube:1643032
# Pointers: L:0, R:118
# N: 474, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 474, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 474, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 474, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:474
# N: 475, Mid: 237, Cube:13312053
# Pointers: L:0, R:237
# N: 475, Mid: 118, Cube:1643032
# Pointers: L:0, R:118
# N: 475, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 475, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 475, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 475, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:475
# N: 476, Mid: 237, Cube:13312053
# Pointers: L:0, R:237
# N: 476, Mid: 118, Cube:1643032
# Pointers: L:0, R:118
# N: 476, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 476, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 476, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 476, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:476
# N: 477, Mid: 238, Cube:13481272
# Pointers: L:0, R:238
# N: 477, Mid: 119, Cube:1685159
# Pointers: L:0, R:119
# N: 477, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 477, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 477, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 477, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:477
# N: 478, Mid: 238, Cube:13481272
# Pointers: L:0, R:238
# N: 478, Mid: 119, Cube:1685159
# Pointers: L:0, R:119
# N: 478, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 478, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 478, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 478, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:478
# N: 479, Mid: 239, Cube:13651919
# Pointers: L:0, R:239
# N: 479, Mid: 119, Cube:1685159
# Pointers: L:0, R:119
# N: 479, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 479, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 479, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 479, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:479
# N: 480, Mid: 239, Cube:13651919
# Pointers: L:0, R:239
# N: 480, Mid: 119, Cube:1685159
# Pointers: L:0, R:119
# N: 480, Mid: 59, Cube:205379
# Pointers: L:0, R:59
# N: 480, Mid: 29, Cube:24389
# Pointers: L:0, R:29
# N: 480, Mid: 14, Cube:2744
# Pointers: L:0, R:14
# N: 480, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:480
# N: 481, Mid: 240, Cube:13824000
# Pointers: L:0, R:240
# N: 481, Mid: 120, Cube:1728000
# Pointers: L:0, R:120
# N: 481, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 481, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 481, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 481, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:481
# N: 482, Mid: 240, Cube:13824000
# Pointers: L:0, R:240
# N: 482, Mid: 120, Cube:1728000
# Pointers: L:0, R:120
# N: 482, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 482, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 482, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 482, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:482
# N: 483, Mid: 241, Cube:13997521
# Pointers: L:0, R:241
# N: 483, Mid: 120, Cube:1728000
# Pointers: L:0, R:120
# N: 483, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 483, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 483, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 483, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:483
# N: 484, Mid: 241, Cube:13997521
# Pointers: L:0, R:241
# N: 484, Mid: 120, Cube:1728000
# Pointers: L:0, R:120
# N: 484, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 484, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 484, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 484, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:484
# N: 485, Mid: 242, Cube:14172488
# Pointers: L:0, R:242
# N: 485, Mid: 121, Cube:1771561
# Pointers: L:0, R:121
# N: 485, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 485, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 485, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 485, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:485
# N: 486, Mid: 242, Cube:14172488
# Pointers: L:0, R:242
# N: 486, Mid: 121, Cube:1771561
# Pointers: L:0, R:121
# N: 486, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 486, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 486, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 486, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:486
# N: 487, Mid: 243, Cube:14348907
# Pointers: L:0, R:243
# N: 487, Mid: 121, Cube:1771561
# Pointers: L:0, R:121
# N: 487, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 487, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 487, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 487, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:487
# N: 488, Mid: 243, Cube:14348907
# Pointers: L:0, R:243
# N: 488, Mid: 121, Cube:1771561
# Pointers: L:0, R:121
# N: 488, Mid: 60, Cube:216000
# Pointers: L:0, R:60
# N: 488, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 488, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 488, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:488
# N: 489, Mid: 244, Cube:14526784
# Pointers: L:0, R:244
# N: 489, Mid: 122, Cube:1815848
# Pointers: L:0, R:122
# N: 489, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 489, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 489, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 489, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:489
# N: 490, Mid: 244, Cube:14526784
# Pointers: L:0, R:244
# N: 490, Mid: 122, Cube:1815848
# Pointers: L:0, R:122
# N: 490, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 490, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 490, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 490, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:490
# N: 491, Mid: 245, Cube:14706125
# Pointers: L:0, R:245
# N: 491, Mid: 122, Cube:1815848
# Pointers: L:0, R:122
# N: 491, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 491, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 491, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 491, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:491
# N: 492, Mid: 245, Cube:14706125
# Pointers: L:0, R:245
# N: 492, Mid: 122, Cube:1815848
# Pointers: L:0, R:122
# N: 492, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 492, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 492, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 492, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:492
# N: 493, Mid: 246, Cube:14886936
# Pointers: L:0, R:246
# N: 493, Mid: 123, Cube:1860867
# Pointers: L:0, R:123
# N: 493, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 493, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 493, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 493, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:493
# N: 494, Mid: 246, Cube:14886936
# Pointers: L:0, R:246
# N: 494, Mid: 123, Cube:1860867
# Pointers: L:0, R:123
# N: 494, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 494, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 494, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 494, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:494
# N: 495, Mid: 247, Cube:15069223
# Pointers: L:0, R:247
# N: 495, Mid: 123, Cube:1860867
# Pointers: L:0, R:123
# N: 495, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 495, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 495, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 495, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:495
# N: 496, Mid: 247, Cube:15069223
# Pointers: L:0, R:247
# N: 496, Mid: 123, Cube:1860867
# Pointers: L:0, R:123
# N: 496, Mid: 61, Cube:226981
# Pointers: L:0, R:61
# N: 496, Mid: 30, Cube:27000
# Pointers: L:0, R:30
# N: 496, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 496, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:496
# N: 497, Mid: 248, Cube:15252992
# Pointers: L:0, R:248
# N: 497, Mid: 124, Cube:1906624
# Pointers: L:0, R:124
# N: 497, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 497, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 497, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 497, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:497
# N: 498, Mid: 248, Cube:15252992
# Pointers: L:0, R:248
# N: 498, Mid: 124, Cube:1906624
# Pointers: L:0, R:124
# N: 498, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 498, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 498, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 498, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:498
# N: 499, Mid: 249, Cube:15438249
# Pointers: L:0, R:249
# N: 499, Mid: 124, Cube:1906624
# Pointers: L:0, R:124
# N: 499, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 499, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 499, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 499, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:499
# N: 500, Mid: 249, Cube:15438249
# Pointers: L:0, R:249
# N: 500, Mid: 124, Cube:1906624
# Pointers: L:0, R:124
# N: 500, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 500, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 500, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 500, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:500
# N: 501, Mid: 250, Cube:15625000
# Pointers: L:0, R:250
# N: 501, Mid: 125, Cube:1953125
# Pointers: L:0, R:125
# N: 501, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 501, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 501, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 501, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:501
# N: 502, Mid: 250, Cube:15625000
# Pointers: L:0, R:250
# N: 502, Mid: 125, Cube:1953125
# Pointers: L:0, R:125
# N: 502, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 502, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 502, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 502, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:502
# N: 503, Mid: 251, Cube:15813251
# Pointers: L:0, R:251
# N: 503, Mid: 125, Cube:1953125
# Pointers: L:0, R:125
# N: 503, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 503, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 503, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 503, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:503
# N: 504, Mid: 251, Cube:15813251
# Pointers: L:0, R:251
# N: 504, Mid: 125, Cube:1953125
# Pointers: L:0, R:125
# N: 504, Mid: 62, Cube:238328
# Pointers: L:0, R:62
# N: 504, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 504, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 504, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:504
# N: 505, Mid: 252, Cube:16003008
# Pointers: L:0, R:252
# N: 505, Mid: 126, Cube:2000376
# Pointers: L:0, R:126
# N: 505, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 505, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 505, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 505, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:505
# N: 506, Mid: 252, Cube:16003008
# Pointers: L:0, R:252
# N: 506, Mid: 126, Cube:2000376
# Pointers: L:0, R:126
# N: 506, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 506, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 506, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 506, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:506
# N: 507, Mid: 253, Cube:16194277
# Pointers: L:0, R:253
# N: 507, Mid: 126, Cube:2000376
# Pointers: L:0, R:126
# N: 507, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 507, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 507, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 507, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:507
# N: 508, Mid: 253, Cube:16194277
# Pointers: L:0, R:253
# N: 508, Mid: 126, Cube:2000376
# Pointers: L:0, R:126
# N: 508, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 508, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 508, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 508, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:508
# N: 509, Mid: 254, Cube:16387064
# Pointers: L:0, R:254
# N: 509, Mid: 127, Cube:2048383
# Pointers: L:0, R:127
# N: 509, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 509, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 509, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 509, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:509
# N: 510, Mid: 254, Cube:16387064
# Pointers: L:0, R:254
# N: 510, Mid: 127, Cube:2048383
# Pointers: L:0, R:127
# N: 510, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 510, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 510, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 510, Mid: 7, Cube:343
# Solved: n = 7
#
# Pointers: L:0, R:510
# N: 511, Mid: 255, Cube:16581375
# Pointers: L:0, R:255
# N: 511, Mid: 127, Cube:2048383
# Pointers: L:0, R:127
# N: 511, Mid: 63, Cube:250047
# Pointers: L:0, R:63
# N: 511, Mid: 31, Cube:29791
# Pointers: L:0, R:31
# N: 511, Mid: 15, Cube:3375
# Pointers: L:0, R:15
# N: 511, Mid: 7, Cube:343
# Solved: n = 7
#
# Congrats: All tests passed! (10 points)

# %% [markdown]
# ###  (B, 0 points)
#
# The inductive invariant for the function `integerCubeRootHelper(n, left, right)` that ensures that the overall algorithm for finding the integer cube root is correct is :
#   $$\text{left}^3 < n\; \text{and}\; \text{right}^3 > n$$
#
#
# Use the inductive invariant to establish that the  integer cube root of $n$ (the final answer we seek) must lie between `left` and `right`.
#
# In other words,  let $j$ be the integer cube root of $n$.
#
# Prove using the inductive invariant and property of the integer cube root $j$ that:
#
# $$ \text{left} \leq j  < \text{right}$$
#
# __Note that this part is not graded. You are encouraged to answer it for your own understanding.__

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### (C, 0 points)
#
# Prove that your solution for `integerCubeRootHelper` maintains the overall inductive invariant from part (B). I.e, if the function were called with
#
# $0 \leq \text{left} < \text{right} < n$, and  $\text{left}^3 < n$ and $\text{right}^3 > n$.
#
# Any subsequent recursive calls will have their arguments that also satisfy this property. Model your answer based on the lecture notes for binary search problem provided.
#
# __Note that this part is not graded. You are encouraged to answer it for your own understanding.__

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Problem 3 (Develop Multiway Merge Algorithm, 15 points).
#
# We studied the problem of merging 2 sorted lists `lst1` and `lst2` into a single sorted list in time $\Theta(m + n)$ where $m$ is the size of `lst1` and $n$ is the size of `lst2`.  Let `twoWayMerge(lst1, lst2)` represent the python function that returns the merged result using the approach presented in class.
#
# In this problem, we will explore algorithms for merging `k` different sorted lists, usually represented as a list of sorted lists into a single list.
#
# ### (A, 0 points)
#
# Suppose we have $k$ lists that we will represent as `lists[0]`, `lists[1]`, ..., `lists[k-1]` for convenience and the size of these lists are all assumed to be the same value $n$.
#
# We wish to solve multiway merge by merging two lists at a time:
#
# ```
#   mergedList = lists[0] # start with list 0
#   for i = 1, ... k-1 do
#       mergedList = twoWayMerge(mergedList, lists[i])
#   return mergedList
# ```
#
# Knowing the running time of the `twoWayMerge` algorithm as mentioned above, what is the overall running time of the algorithm in terms of $n, k$.
#
# __Note that this part is not graded. You are encouraged to answer it for your own understanding.__

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# __(B)__ Implement an algorithm that will implement the $k$ way merge by calling `twoWayMerge` repeatedly as follows:
#   1. Call `twoWayMerge` on consecutive pairs of lists `twoWayMerge(lists[0], lists[1])`, ... , `twoWayMerge(lists[k-2], lists[k-1])` (assume k is even).
#   2. Thus, we create a new list of lists of size `k/2`.
#   3. Repeat steps 1, 2 until we have a single list left.

# %%
def twoWayMerge(lst1, lst2):
    # Implement the two way merge algorithm on 
    #          two ascending order sorted lists
    # return a fresh ascending order sorted list that 
    #          merges lst1 and lst2
    # your code here
    temp_store = []  # Initialize the merged list
    i = 0
    j = 0

    while i < len(lst1) and j < len(lst2):
        if lst1[i] < lst2[j]:
            temp_store.append(lst1[i])
            i += 1
        else:
            temp_store.append(lst2[j])
            j += 1

    # Append any remaining elements from lst1 (if any)
    while i < len(lst1):
        temp_store.append(lst1[i])
        i += 1

    # Append any remaining elements from lst2 (if any)
    while j < len(lst2):
        temp_store.append(lst2[j])
        j += 1

    return temp_store

# %%
# given a list_of_lists as input, 
#   if list_of_lists has 2 or more lists, 
#        compute 2 way merge on elements i, i+1 for i = 0, 2, ...
#   return new list of lists after the merge
#   Handle the case when the list size is odd carefully.
def oneStepKWayMerge(list_of_lists):
    if (len(list_of_lists) <= 1):
        return list_of_lists
    ret_list_of_lists = []
    k = len(list_of_lists)
    for i in range(0, k, 2):
        if (i < k-1):
            ret_list_of_lists.append(twoWayMerge(list_of_lists[i], list_of_lists[i+1]))
        else: 
            ret_list_of_lists.append(list_of_lists[k-1])
    return ret_list_of_lists

# %%
# Given a list of lists wherein each 
#    element of list_of_lists is sorted in ascending order,
# use the oneStepKWayMerge function repeatedly to merge them.
# Return a single merged list that is sorted in ascending order.
def kWayMerge(list_of_lists):
    k = len(list_of_lists)
    if k == 1:
        return list_of_lists[0]
    else:
        new_list_of_lists = oneStepKWayMerge(list_of_lists)
        return kWayMerge(new_list_of_lists)

# %%
# BEGIN TESTS
lst1= kWayMerge([[1,2,3], [4,5,7],[-2,0,6],[5]])
assert lst1 == [-2, 0, 1, 2, 3, 4, 5, 5, 6, 7], "Test 1 failed"

lst2 = kWayMerge([[-2, 4, 5 , 8], [0, 1, 2], [-1, 3,6,7]])
assert lst2 == [-2, -1, 0, 1, 2, 3, 4, 5, 6, 7, 8], "Test 2 failed"

lst3 = kWayMerge([[-1, 1, 2, 3, 4, 5]])
assert lst3 == [-1, 1, 2, 3, 4, 5], "Test 3 Failed"

print('All Tests Passed = 15 points')
#END TESTS
# Out:
# All Tests Passed = 15 points

# %% [markdown]
# ### (C, 0 points)
#
# What is the overall running time of the algorithm in (B) as a function of $n$ and $k$?
#
# __Note that this part is not graded. You are encouraged to answer it for your own understanding.__

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Solutions to the Conceptual (Non Coding) Questions
#
# ### Problem 1B
# Note that the running time of _findCrossOverIndexHelper_ for inputs $x,y$ of size $n$ is $\Theta(\log(n))$. This is because, each iteration of the algorithm halves the search region and the algorithm terminates when the search region has size $2$. This requires at most $\Theta(\log(n))$ iterations by the same argument as that presented for binary search in the lecture video.
#
# ### Problem 2B
#
#
#
# #### The reason we can conclude $\text{left} \leq j < \text{right}$ is :
#
#
#
# We note that since $j$ is assumed to be integer cube root of $n$, we have
# $j^3 \leq n$ and  $(j+1)^3 > n$. We have $\text{left} < j+1$ and likewise $\text{right} > j$. Therefore, $\text{left} \leq j < \text{right}$.
#
# ### Problem 2C
#
# ~~~
#     mid = (left + right)//2
#     if (cube(mid)  <= n and cube(mid+1) > n):
#         return mid
#     elif (cube(mid) > n):
#         return integerCubeRootHelper(n, left, mid) # Call 1
#     else:
#         return integerCubeRootHelper(n, mid, right) # Call 2
# ~~~
#
# If Call 1 happens, we note that   `cube(mid) > n`. However, `cube(left) < n` is already true since the value of `left` is unchanged. Thus Call 1 satisfies the invariant.
#
# Note that Call 2 will satisfy the property because  `cube(right) > n` and the call will only happen if
# `cube(mid+1) <= n`. This implies that `cube(mid)< n`. Therefore, we conclude that `Call 2` will satisfy
# the invariant, as well.
#
#
# ### Problem 3A
#
# The overall running time is $\Theta( n \times ( (k-1) + \cdots + 1))= \Theta(n \times k^2)$
#
# ### Problem 3C
#
# At iteration $i$, the list of lists has size $k/2^{i-1}$ with each element of size $n \times 2^{i-1}$. The number of merge operations is
# $k/2^i$ with each merge operation taking $n \times 2^{i}$ time. The overall work done at the $i^{th}$ iteration remains $k \times n$. There are $\Theta(\log(k))$ iterations in all. Therefore, the overall complexity is $\Theta(n k \log(k))$.

# %% [markdown]
# ## That's All Folks!
